# %% [markdown]
# ## Q1.
# ####  Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# The Pearson correlation coefficient, often denoted as \( r \), is a statistical measure that quantifies the strength and direction of a linear relationship between two variables. It ranges from -1 to 1, where:
#
# - \( r = 1 \) indicates a perfect positive linear relationship.
# - \( r = -1 \) indicates a perfect negative linear relationship.
# - \( r = 0 \) indicates no linear relationship.
#
# To calculate the Pearson correlation coefficient between the amount of time students spend studying for an exam (\( X \)) and their final exam scores (\( Y \)), you would typically follow these steps:
#
# 1. Calculate the mean (\( \bar{X} \)) and standard deviation (\( s_X \)) of the studying time variable (\( X \)).
# 2. Calculate the mean (\( \bar{Y} \)) and standard deviation (\( s_Y \)) of the exam scores variable (\( Y \)).
# 3. Calculate the covariance (\( \text{cov}(X, Y) \)) between the two variables.
# 4. Calculate the Pearson correlation coefficient using the formula:
#
# \[ r = \frac{\text{cov}(X, Y)}{s_X \cdot s_Y} \]
#
# Now, let's interpret the result:
#
# - If \( r \) is close to 1, it suggests a strong positive linear relationship. This would mean that as the amount of time spent studying increases, final exam scores tend to increase.
# - If \( r \) is close to -1, it indicates a strong negative linear relationship. In this case, as the time spent studying increases, final exam scores tend to decrease.
# - If \( r \) is close to 0, it implies a weak or no linear relationship. The amount of time spent studying does not have a strong linear association with final exam scores.
#
# It's important to note that correlation does not imply causation. Even if a strong correlation is found, it does not necessarily mean that studying more directly causes higher exam scores; other factors may be influencing the relationship.
#
# Additionally, outliers in the data can strongly affect the correlation coefficient, so it's important to visually inspect the data and consider other statistical measures as well.

# %% [markdown]
# ## Q2.
# #### Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## Q3.
#
# #### Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# ![22.png](attachment:22.png)

# %% [markdown]
# ![33.png](attachment:33.png)

# %% [markdown]
# ## Q4.
# ### A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# ![111.png](attachment:111.png)

# %% [markdown]
# ![222.png](attachment:222.png)

# %% [markdown]
# ## Q5.
# #### A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:

# %% [markdown]
# ![300.png](attachment:300.png)

# %% [markdown]
# It seems like you've provided a list of ages and corresponding soft drink preferences. To examine the relationship between age and the preference for a particular brand of soft drink, you could use various statistical measures. However, for the purpose of correlation, we typically deal with numerical data. In this case, you might want to assign numerical values to the soft drink preferences and then calculate the correlation.
#
# Let's assume that you assign numerical values to the soft drink preferences, for example:
# - Coke: 1
# - Pepsi: 2
# - Mountain Dew: 3
#
# Here's the modified data:
#
# ```
# Age     | Soft Drink
# --------|------------
# 25      | 1 (Coke)
# 42      | 2 (Pepsi)
# 37      | Not specified
# 19      | Not specified
# 31      | Not specified
# 28      | 3 (Mountain Dew)
#          | 1 (Coke)
#          | 2 (Pepsi)
#          | 1 (Coke)
# ```
#
# Now, you can calculate the correlation coefficient. However, it's important to note that with this small dataset, calculating a meaningful correlation might be challenging. Also, the lack of specific numerical values for some preferences (labeled as "Not specified") might affect the accuracy of the correlation.
#
# If you still want to proceed with the calculation, you can follow these steps:
#
# 1. Assign numerical values to the soft drink preferences.
# 2. Calculate the correlation coefficient, either Pearson or Spearman, depending on the nature of the relationship (linear or monotonic).
#
# Remember, correlation does not imply causation, and the small sample size may limit the generalizability of your findings. It's always a good idea to interpret the results cautiously and consider other factors that might influence the relationship between age and soft drink preferences.

# %% [markdown]
# ## Q6.
# #### A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# #### Completed 22th_March_Assignment
