# %% [markdown]
# # Q1.
# ## List any five functions of the pandas library with execution.

# %%
#(1): read_csv
#_______________________________________

import pandas as pd 
df  = pd.read_csv("d1.csv")
display(df)
# Out:
#         day    temperature  windspeed  event
# 0  01/01/2017           32          6   Rain
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow
# 3  04/01/2017           24          7   Snow
# 4  05/01/2017           32          4  Rain
# 5  06/01/2017           32          2  Sunny

# %%
#(2): head()
#________________________________________________

display(df.head())
display(df.head(3))
# Out:
#         day    temperature  windspeed  event
# 0  01/01/2017           32          6   Rain
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow
# 3  04/01/2017           24          7   Snow
# 4  05/01/2017           32          4  Rain
#         day    temperature  windspeed  event
# 0  01/01/2017           32          6   Rain
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow

# %%
#(3):tail()
#___________________________________


display(df.tail())
display(df.tail(2))
# Out:
#         day    temperature  windspeed  event
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow
# 3  04/01/2017           24          7   Snow
# 4  05/01/2017           32          4  Rain
# 5  06/01/2017           32          2  Sunny
#         day    temperature  windspeed  event
# 4  05/01/2017           32          4  Rain
# 5  06/01/2017           32          2  Sunny

# %%
#(4):describe()
#___________________________________

display(df)
df.describe()
# Out:
#         day    temperature  windspeed  event
# 0  01/01/2017           32          6   Rain
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow
# 3  04/01/2017           24          7   Snow
# 4  05/01/2017           32          4  Rain
# 5  06/01/2017           32          2  Sunny
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.500000   4.666667
# std       3.885872   2.338090
# min      24.000000   2.000000
# 25%      29.000000   2.500000
# 50%      32.000000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
#(5):loc[:]
#__________________________________________

display(df)

df.loc[1:3]
# Out:
#         day    temperature  windspeed  event
# 0  01/01/2017           32          6   Rain
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow
# 3  04/01/2017           24          7   Snow
# 4  05/01/2017           32          4  Rain
# 5  06/01/2017           32          2  Sunny
#         day    temperature  windspeed  event
# 1  02/01/2017           35          7  Sunny
# 2  03/01/2017           28          2   Snow
# 3  04/01/2017           24          7   Snow

# %% [markdown]
# # Q2.
# ### Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
import pandas as pd 
data = {
        'A':[1,2,3,4],
        'B':[10,20,30,40],
        'C':[11,22,33,44]
}
df  = pd.DataFrame(data)
display(df)
# Out:
#    A   B   C
# 0  1  10  11
# 1  2  20  22
# 2  3  30  33
# 3  4  40  44

# %%
df1  = pd.DataFrame(data,index = [1,2,3,4])
display(df1)
# Out:
#    A   B   C
# 1  1  10  11
# 2  2  20  22
# 3  3  30  33
# 4  4  40  44

# %% [markdown]
# # Q3.
# ### You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.
#
# **For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.**

# %%
import pandas as pd 
df = pd.read_csv("data.csv")
display(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
sum = 0
for i in range(3):
    sum  = sum + df['Maxpulse'].loc[i]

print("First Three entries of the DataFrame of column 'Maxpulse' : {}".format(sum))
# Out:
# First Three entries of the DataFrame of column 'Maxpulse' : 410

# %% [markdown]
# # Q4.
# ### Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
import pandas as pd 
data = {
         'Student Name':['Ajay','Vijay','Gopu','Mithi','Mithu'],
         'Roll No.' : [11,22,33,44,55],
         'Marks':[89,90,50,100,100],
         'Teacher-FeedBack':['Good student','Need to be very hard work','Need to clear all your doubts of the topic','Brilliant Student','Intelligent Student']
}
df  = pd.DataFrame(data)
display(df)
# Out:
#   Student Name  Roll No.  Marks                            Teacher-FeedBack
# 0         Ajay        11     89                                Good student
# 1        Vijay        22     90                   Need to be very hard work
# 2         Gopu        33     50  Need to clear all your doubts of the topic
# 3        Mithi        44    100                           Brilliant Student
# 4        Mithu        55    100                         Intelligent Student

# %%
len(df.index)
# Out:
# 5

# %%
wc = []
for i in range(len(df.index)):
    x = df['Teacher-FeedBack'].loc[i].split()
    count = 0
    for j in x:
        for k in j:
            count+=1
    wc.append(count)
df['Word_Count']= wc    
display(df)
# Out:
#   Student Name  Roll No.  Marks                            Teacher-FeedBack  \
# 0         Ajay        11     89                                Good student
# 1        Vijay        22     90                   Need to be very hard work
# 2         Gopu        33     50  Need to clear all your doubts of the topic
# 3        Mithi        44    100                           Brilliant Student
# 4        Mithu        55    100                         Intelligent Student
#
#    Word_Count
# 0          11
# 1          20
# 2          34
# 3          16
# 4          18

# %% [markdown]
# # Q5.
# ### How are DataFrame.size() and DataFrame.shape() different?

# %%
import pandas as pd 
df  = pd.read_csv("data.csv")
display(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# **it describe the number of elements in the dataFrame**

# %%
df.size
# Out:
# 676

# %% [markdown]
# **it describe the dimension of the dataFrame**

# %%
df.shape
# Out:
# (169, 4)

# %% [markdown]
# # Q6.
# ### Which function of pandas do we use to read an excel file?

# %% [markdown]
# ### Answer:
# **pandas.read_excel("excel filename")**
#
# ***it returns the DataFrame***

# %% [markdown]
# # Q7.
# ### You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
# #### The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
x = 'iitb.ajaykumar@gmail.com'
x.split('@')
# Out:
# ['iitb.ajaykumar', 'gmail.com']

# %%
import pandas as pd 
data = {
    'Name':['Ajay','Mithi','Mithu','VikramAditya'],
    'Class':['X','XI','XII','B.Tech'],
    'Stream':['Science','Medical','Maths','Engineering'],
    'Email_Id':['iitb.ajaykumar@gmail.com','stanford-uni@std.ac.in','mit.mithu@mit.ac.in','stanford-uni@std.ac.in']
}
df  = pd.DataFrame(data)
display(df)
# Out:
#            Name   Class       Stream                  Email_Id
# 0          Ajay       X      Science  iitb.ajaykumar@gmail.com
# 1         Mithi      XI      Medical    stanford-uni@std.ac.in
# 2         Mithu     XII        Maths       mit.mithu@mit.ac.in
# 3  VikramAditya  B.Tech  Engineering    stanford-uni@std.ac.in

# %%
len(df.index)
# Out:
# 4

# %%
temp = []
for i in range(len(df.index)):
    x = df['Email_Id'].loc[i]
    y = x.split('@')
    temp.append(y)
     
df['UserName'] = temp
display(df)
# Out:
#            Name   Class       Stream                  Email_Id  \
# 0          Ajay       X      Science  iitb.ajaykumar@gmail.com
# 1         Mithi      XI      Medical    stanford-uni@std.ac.in
# 2         Mithu     XII        Maths       mit.mithu@mit.ac.in
# 3  VikramAditya  B.Tech  Engineering    stanford-uni@std.ac.in
#
#                       UserName
# 0  [iitb.ajaykumar, gmail.com]
# 1    [stanford-uni, std.ac.in]
# 2       [mit.mithu, mit.ac.in]
# 3    [stanford-uni, std.ac.in]

# %% [markdown]
# # Q8.
# #### You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.
# **For example, if df contains the following values:**

# %% [raw]
#     A B C
#   0 3 5 1
#   1 8 2 7
#   2 6 9 4
#   3 2 3 5
#   4 9 1 2
#  Your function should select the following rows:
#     A B C
#   1 8 2 7
#   4 9 1 2
#  The function should return a new DataFrame that contains only the selected rows.

# %%
import pandas as pd 
data  = {
          'A':[3,8,6,2,9],
          'B':[5,2,9,3,1],
          'C':[1,7,4,5,2]
}
df  = pd.DataFrame(data)
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
df1  = df[(df['A']>5) & (df['B']<10)]
df1
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# # Q9.
# #### Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
import pandas as pd 
df  = pd.read_csv("data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print("Mean:")
display(df.mean())
print("Median:")
display(df.median())
print("Mode:")
display(df.mode())
print("Standard Deviation:")
display(df.std())
# Out:
# Mean:
# Duration     63.846154
# Pulse       107.461538
# Maxpulse    134.047337
# Calories    375.790244
# dtype: float64
# Median:
# Duration     60.0
# Pulse       105.0
# Maxpulse    131.0
# Calories    318.6
# dtype: float64
# Mode:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    100       120     300.0
# Standard Deviation:
# Duration     42.299949
# Pulse        14.510259
# Maxpulse     16.450434
# Calories    266.379919
# dtype: float64

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# # Q10.
# ### Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# **create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for  each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.**

# %% [markdown]
# # Answer:
# #### Simple Moving Average (SMA)
# ***A simple moving average tells us the unweighted mean of the previous K data points. The more the value of K the more smooth is the curve, but increasing K decreases accuracy. If the data points are p1,  p2, . . . , pn then we calculate the simple moving average.***

# %% [markdown]
# ![1.gif](attachment:1.gif)

# %% [markdown]
# In Python, we can calculate the moving average using **.rolling()** method. This method provides rolling windows over the data, and we can use the mean function over these windows to calculate moving averages. The size of the window is passed as a parameter in the **function .rolling(window)**.

# %% [markdown]
# **To calculate SMA in Python** we will use Pandas dataframe.rolling() function that helps us to make calculations on a rolling window. On the rolling window, we will use .mean() function to calculate the mean of each window.
#
# Syntax: DataFrame.rolling(window, min_periods=None, center=False, win_type=None, on=None, axis=0).mean()
#
# Parameters :
#
# window : Size of the window. That is how many observations we have to take for the calculation of each window.
# min_periods : Least number of observations in a window required to have a value (otherwise result is NA).
# center : It is used to set the labels at the center of the window.
# win_type : It is used to set the window type.
# on : Datetime column of our dataframe on which we have to calculate rolling mean.
# axis : integer or string, default 0

# %%
# importing Libraries

# importing pandas as pd
import pandas as pd

# importing numpy as np
# for Mathematical calculations
import numpy as np

# importing pyplot from matplotlib as plt
# for plotting graphs
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
# importing time-series data
reliance = pd.read_csv('RELIANCE.NS_.csv', index_col='Date',parse_dates=True)

# Printing dataFrame
reliance.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-07-21  507.192322  507.687622  497.781525  498.450195  485.688568
# 2016-07-22  498.276825  504.121429  497.831055  502.660278  489.790863
# 2016-07-25  502.239258  507.068512  498.945496  506.573181  493.603546
# 2016-07-26  506.697021  512.541626  502.833649  507.217102  494.231049
# 2016-07-27  506.721771  508.182922  499.737976  501.793488  488.946259
#
#                Volume
# Date
# 2016-07-21  3097170.0
# 2016-07-22  3184126.0
# 2016-07-25  3803482.0
# 2016-07-26  4853316.0
# 2016-07-27  5090697.0

# %%
# updating our dataFrame to have only
# one column 'Close' as rest all columns
# are of no use for us at the moment
# using .to_frame() to convert pandas series
# into dataframe.
reliance = reliance['Close'].to_frame()

# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 7
reliance['SMA7'] = reliance['Close'].rolling(7).mean()

# removing all the NULL values using
# dropna() method
reliance.dropna(inplace=True)

# printing Dataframe
reliance
# Out:
#                   Close         SMA7
# Date
# 2017-01-27   507.737152   507.875139
# 2017-01-30   517.494690   508.741926
# 2017-01-31   517.692810   509.555642
# 2017-02-01   519.896912   511.243221
# 2017-02-02   516.850769   513.196136
# ...                 ...          ...
# 2021-07-14  2086.000000  2095.492885
# 2021-07-15  2082.350098  2089.428606
# 2021-07-16  2112.399902  2089.764300
# 2021-07-19  2098.949951  2090.671422
# 2021-07-20  2093.800049  2093.900007
#
# [1046 rows x 2 columns]

# %%
# plotting Close price and simple
# moving average of 30 days using .plot() method
reliance[['Close', 'SMA7']].plot(label='RELIANCE',figsize=(16, 8))

# %% [markdown]
# # Q11.
# ### You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g. Monday, Tuesday) corresponding to each date in the 'Date' column.
#
# **For example, if df contains the following values:**

# %% [raw]
#     Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
#
# Your function should create the following DataFrame:
#     Date     Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
#
# The function should return the modified DataFrame.

# %%
import pandas as pd 
import datetime
data  = {"dates" :         [datetime.date(2023, 1, 1),  
                            datetime.date(2023, 1, 2),
                            datetime.date(2023, 1, 3),
                            datetime.date(2023, 1, 4),
                            datetime.date(2023, 1, 5)]}
df = pd.DataFrame(data)
display(df)
# Out:
#         dates
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
df["Weekday"]    = df["dates"].apply(lambda x: datetime.datetime.strftime(x, '%A')) 
df["Day Number"] = df["dates"].apply(lambda x: str(datetime.datetime.weekday(x)))

display(df)
# Out:
#         dates    Weekday Day Number
# 0  2023-01-01     Sunday          6
# 1  2023-01-02     Monday          0
# 2  2023-01-03    Tuesday          1
# 3  2023-01-04  Wednesday          2
# 4  2023-01-05   Thursday          3

# %% [markdown]
# # Q12.
# ### Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
import pandas as pd

def Time_series(date, per):
    date_series = pd.date_range(date, periods=per)
    print(date_series)
    res = pd.Series(date_series)
    result = res.to_frame()                # to convert Series into DataFrame
    result.columns = ['Date']
    display(result)

date = "2023-01-01"
per = 31
Time_series(date, per)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31'],
#               dtype='datetime64[ns]', freq='D')
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# ...

# %% [markdown]
# # Q13.
# ### To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# ## Answer:
#   ##### import pandas

# %% [markdown]
# ***Completed 24Feb_Assignment**
# ## ____________________________________________________________
